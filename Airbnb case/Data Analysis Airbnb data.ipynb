# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Alvin\Dataset\airbnb prices.csv')

# %%
df
# Out:
#         room_id  survey_id    host_id     room_type  country       city  \
# 0      10176931       1476   49180562   Shared room      NaN  Amsterdam
# 1       8935871       1476   46718394   Shared room      NaN  Amsterdam
# 2      14011697       1476   10346595   Shared room      NaN  Amsterdam
# 3       6137978       1476    8685430   Shared room      NaN  Amsterdam
# 4      18630616       1476   70191803   Shared room      NaN  Amsterdam
# ...         ...        ...        ...           ...      ...        ...
# 18718  17789893       1476   47501089  Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870  Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632  Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569  Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013  Private room      NaN  Amsterdam
#
#        borough             neighborhood  reviews  overall_satisfaction  \
# ...

# %%
df.isnull().sum()
# Out:
# room_id                     0
# survey_id                   0
# host_id                     0
# room_type                   0
# country                 18723
# city                        0
# borough                 18723
# neighborhood                0
# reviews                     0
# overall_satisfaction        0
# accommodates                0
# bedrooms                    0
# bathrooms               18723
# price                       0
# minstay                 18723
# name                       52
# last_modified               0
# latitude                    0
# longitude                   0
# location                    0
# dtype: int64

# %%
df.room_type.unique()
# Out:
# array(['Shared room', 'Entire home/apt', 'Private room'], dtype=object)

# %% [markdown]
# ### Drop the Shared room

# %%
df = df[-(df.room_type == 'Shared room')]

# %%
df
# Out:
#         room_id  survey_id    host_id        room_type  country       city  \
# 33     10201214       1476    8497487  Entire home/apt      NaN  Amsterdam
# 34      3119298       1476   15847782  Entire home/apt      NaN  Amsterdam
# 35      5372074       1476   14390964  Entire home/apt      NaN  Amsterdam
# 36     10511291       1476    5421078  Entire home/apt      NaN  Amsterdam
# 37     18047871       1476    9302267  Entire home/apt      NaN  Amsterdam
# ...         ...        ...        ...              ...      ...        ...
# 18718  17789893       1476   47501089     Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870     Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632     Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569     Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013     Private room      NaN  Amsterdam
#
# ...

# %% [markdown]
# ### Take a count of each neighborhood to show the popularity

# %%
df.neighborhood.value_counts()
# Out:
# De Baarsjes / Oud West                    3280
# De Pijp / Rivierenbuurt                   2371
# Centrum West                              2217
# Centrum Oost                              1724
# Westerpark                                1424
# Noord-West / Noord-Midden                 1416
# Oud Oost                                  1167
# Bos en Lommer                              985
# Oostelijk Havengebied / Indische Buurt     916
# Watergraafsmeer                            515
# Oud Noord                                  492
# Ijburg / Eiland Zeeburg                    378
# Slotervaart                                346
# Buitenveldert / Zuidas                     248
# Noord West                                 241
# Noord Oost                                 221
# Geuzenveld / Slotermeer                    192
# Osdorp                                     161
# De Aker / Nieuw Sloten                     114
# Bijlmer Centrum                             98
# ...

# %% [markdown]
# ### Number of reviews that is given for

# %%
df.reviews.value_counts()
# Out:
# 0      2975
# 1      1500
# 2      1238
# 3      1100
# 4       924
#        ...
# 310       1
# 390       1
# 447       1
# 215       1
# 183       1
# Name: reviews, Length: 283, dtype: int64

# %% [markdown]
# ### The overall_satisfaction count by each rating

# %%
df.overall_satisfaction.value_counts()
# Out:
# 5.0    7697
# 0.0    5721
# 4.5    4543
# 4.0     573
# 3.5     105
# 3.0      19
# 2.5       1
# 1.0       1
# Name: overall_satisfaction, dtype: int64

# %% [markdown]
# ### Create a sub dataset where overall satisfaction is 0

# %%
sub_df = df[df.overall_satisfaction == 0]

# %%
sub_df
# Out:
#         room_id  survey_id    host_id        room_type  country       city  \
# 34      3119298       1476   15847782  Entire home/apt      NaN  Amsterdam
# 36     10511291       1476    5421078  Entire home/apt      NaN  Amsterdam
# 37     18047871       1476    9302267  Entire home/apt      NaN  Amsterdam
# 38      7468232       1476    7215538  Entire home/apt      NaN  Amsterdam
# 40      5818567       1476   29561840  Entire home/apt      NaN  Amsterdam
# ...         ...        ...        ...              ...      ...        ...
# 18708  16411584       1476   83673574     Private room      NaN  Amsterdam
# 18709  12886265       1476   50843183     Private room      NaN  Amsterdam
# 18714  19203256       1476  132265798     Private room      NaN  Amsterdam
# 18715  19734178       1476  139135665     Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632     Private room      NaN  Amsterdam
#
#        borough                            neighborhood  reviews  \
# ...

# %% [markdown]
# ### Describe the dataset

# %%
df.describe()
# Out:
#             room_id  survey_id       host_id  country  borough       reviews  \
# count  1.866000e+04    18660.0  1.866000e+04      0.0      0.0  18660.000000
# mean   1.120262e+07     1476.0  3.575860e+07      NaN      NaN     16.729207
# std    6.084245e+06        0.0  3.758082e+07      NaN      NaN     33.506653
# min    2.818000e+03     1476.0  2.234000e+03      NaN      NaN      0.000000
# 25%    6.047014e+06     1476.0  7.125411e+06      NaN      NaN      2.000000
# 50%    1.228306e+07     1476.0  1.987107e+07      NaN      NaN      6.000000
# 75%    1.661017e+07     1476.0  5.201818e+07      NaN      NaN     17.000000
# max    2.000373e+07     1476.0  1.418319e+08      NaN      NaN    532.000000
#
#        overall_satisfaction  accommodates      bedrooms  bathrooms  \
# count          18660.000000  18660.000000  18660.000000        0.0
# mean               3.303778      2.921543      1.431833        NaN
# std                2.213003      1.319141      0.880145        NaN
# ...

# %% [markdown]
# ### The satisfaction ratings where bedroom is 3

# %%
df.head(1)
# Out:
#      room_id  survey_id  host_id        room_type  country       city  \
# 33  10201214       1476  8497487  Entire home/apt      NaN  Amsterdam
#
#     borough             neighborhood  reviews  overall_satisfaction  \
# 33      NaN  Ijburg / Eiland Zeeburg       19                   5.0
#
#     accommodates  bedrooms  bathrooms  price  minstay  \
# 33             8       4.0        NaN  763.0      NaN
#
#                                  name               last_modified   latitude  \
# 33  Beautiful Watervilla in Amsterdam  2017-07-23 13:02:10.468528  52.348254
#
#     longitude                                           location
# 33   5.001477  0101000020E6100000E7C8CA2F83011440C0594A96932C...

# %%
df[df.bedrooms == 3].overall_satisfaction.value_counts()
# Out:
# 0.0    635
# 5.0    515
# 4.5    266
# 4.0     22
# 3.5      5
# 2.5      1
# Name: overall_satisfaction, dtype: int64

# %% [markdown]
# ### The satisfaction ratings count where price is greater than equal to 150 but less than equal to 180

# %%
df.head(1)
# Out:
#      room_id  survey_id  host_id        room_type  country       city  \
# 33  10201214       1476  8497487  Entire home/apt      NaN  Amsterdam
#
#     borough             neighborhood  reviews  overall_satisfaction  \
# 33      NaN  Ijburg / Eiland Zeeburg       19                   5.0
#
#     accommodates  bedrooms  bathrooms  price  minstay  \
# 33             8       4.0        NaN  763.0      NaN
#
#                                  name               last_modified   latitude  \
# 33  Beautiful Watervilla in Amsterdam  2017-07-23 13:02:10.468528  52.348254
#
#     longitude                                           location
# 33   5.001477  0101000020E6100000E7C8CA2F83011440C0594A96932C...

# %%
df[(df.price >= 150) & (df.price <= 180)]
# Out:
#         room_id  survey_id    host_id        room_type  country       city  \
# 46     17682178       1476   42934313  Entire home/apt      NaN  Amsterdam
# 47     14060573       1476   82283309  Entire home/apt      NaN  Amsterdam
# 48     19992596       1476   62831267  Entire home/apt      NaN  Amsterdam
# 89     16416572       1476   15586027  Entire home/apt      NaN  Amsterdam
# 90     14975839       1476    6715716  Entire home/apt      NaN  Amsterdam
# ...         ...        ...        ...              ...      ...        ...
# 16025  14604039       1476   89466350     Private room      NaN  Amsterdam
# 16026    579851       1476    2851886     Private room      NaN  Amsterdam
# 16027     27886       1476      97647     Private room      NaN  Amsterdam
# 16028   4763797       1476   24579161     Private room      NaN  Amsterdam
# 16029  19803135       1476  139869638     Private room      NaN  Amsterdam
#
# ...

# %% [markdown]
# ### Find out the count of each accomodation value to understand where is the most availability

# %%
df.head(1)
# Out:
#      room_id  survey_id  host_id        room_type  country       city  \
# 33  10201214       1476  8497487  Entire home/apt      NaN  Amsterdam
#
#     borough             neighborhood  reviews  overall_satisfaction  \
# 33      NaN  Ijburg / Eiland Zeeburg       19                   5.0
#
#     accommodates  bedrooms  bathrooms  price  minstay  \
# 33             8       4.0        NaN  763.0      NaN
#
#                                  name               last_modified   latitude  \
# 33  Beautiful Watervilla in Amsterdam  2017-07-23 13:02:10.468528  52.348254
#
#     longitude                                           location
# 33   5.001477  0101000020E6100000E7C8CA2F83011440C0594A96932C...

# %%
df.accommodates.value_counts()
# Out:
# 2     9996
# 4     5563
# 3     1583
# 6      475
# 5      470
# 1      355
# 8      105
# 7       52
# 16      18
# 10      16
# 12       9
# 9        8
# 14       6
# 11       2
# 13       1
# 17       1
# Name: accommodates, dtype: int64

# %% [markdown]
# ### On which price most of the properties are available

# %%
df.head(1)
# Out:
#      room_id  survey_id  host_id        room_type  country       city  \
# 33  10201214       1476  8497487  Entire home/apt      NaN  Amsterdam
#
#     borough             neighborhood  reviews  overall_satisfaction  \
# 33      NaN  Ijburg / Eiland Zeeburg       19                   5.0
#
#     accommodates  bedrooms  bathrooms  price  minstay  \
# 33             8       4.0        NaN  763.0      NaN
#
#                                  name               last_modified   latitude  \
# 33  Beautiful Watervilla in Amsterdam  2017-07-23 13:02:10.468528  52.348254
#
#     longitude                                           location
# 33   5.001477  0101000020E6100000E7C8CA2F83011440C0594A96932C...

# %%
df.price.value_counts()
# Out:
# 119.0     1023
# 180.0      999
# 144.0      886
# 150.0      621
# 132.0      587
#           ...
# 1016.0       1
# 328.0        1
# 1134.0       1
# 585.0        1
# 413.0        1
# Name: price, Length: 419, dtype: int64

# %% [markdown]
# ### The proportion of each bedroom values in overall bedroom values

# %%
df.head(1)
# Out:
#      room_id  survey_id  host_id        room_type  country       city  \
# 33  10201214       1476  8497487  Entire home/apt      NaN  Amsterdam
#
#     borough             neighborhood  reviews  overall_satisfaction  \
# 33      NaN  Ijburg / Eiland Zeeburg       19                   5.0
#
#     accommodates  bedrooms  bathrooms  price  minstay  \
# 33             8       4.0        NaN  763.0      NaN
#
#                                  name               last_modified   latitude  \
# 33  Beautiful Watervilla in Amsterdam  2017-07-23 13:02:10.468528  52.348254
#
#     longitude                                           location
# 33   5.001477  0101000020E6100000E7C8CA2F83011440C0594A96932C...

# %%
df.bedrooms.value_counts()
# Out:
# 1.0     11038
# 2.0      4456
# 3.0      1444
# 0.0      1154
# 4.0       473
# 5.0        62
# 6.0        19
# 10.0        5
# 7.0         4
# 8.0         3
# 9.0         2
# Name: bedrooms, dtype: int64

# %% [markdown]
# ### Drop the values where bedroom are equal to zero

# %%
df[-(df.bedrooms == 0)]
# Out:
#         room_id  survey_id    host_id        room_type  country       city  \
# 33     10201214       1476    8497487  Entire home/apt      NaN  Amsterdam
# 34      3119298       1476   15847782  Entire home/apt      NaN  Amsterdam
# 35      5372074       1476   14390964  Entire home/apt      NaN  Amsterdam
# 36     10511291       1476    5421078  Entire home/apt      NaN  Amsterdam
# 37     18047871       1476    9302267  Entire home/apt      NaN  Amsterdam
# ...         ...        ...        ...              ...      ...        ...
# 18718  17789893       1476   47501089     Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870     Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632     Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569     Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013     Private room      NaN  Amsterdam
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18660 entries, 33 to 18722
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_id               18660 non-null  int64
#  1   survey_id             18660 non-null  int64
#  2   host_id               18660 non-null  int64
#  3   room_type             18660 non-null  object
#  4   country               0 non-null      float64
#  5   city                  18660 non-null  object
#  6   borough               0 non-null      float64
#  7   neighborhood          18660 non-null  object
#  8   reviews               18660 non-null  int64
#  9   overall_satisfaction  18660 non-null  float64
#  10  accommodates          18660 non-null  int64
#  11  bedrooms              18660 non-null  float64
#  12  bathrooms             0 non-null      float64
#  13  price                 18660 non-null  float64
#  14  minstay               0 non-null      float64
# ...

# %%
df.describe()
# Out:
#             room_id  survey_id       host_id  country  borough       reviews  \
# count  1.866000e+04    18660.0  1.866000e+04      0.0      0.0  18660.000000
# mean   1.120262e+07     1476.0  3.575860e+07      NaN      NaN     16.729207
# std    6.084245e+06        0.0  3.758082e+07      NaN      NaN     33.506653
# min    2.818000e+03     1476.0  2.234000e+03      NaN      NaN      0.000000
# 25%    6.047014e+06     1476.0  7.125411e+06      NaN      NaN      2.000000
# 50%    1.228306e+07     1476.0  1.987107e+07      NaN      NaN      6.000000
# 75%    1.661017e+07     1476.0  5.201818e+07      NaN      NaN     17.000000
# max    2.000373e+07     1476.0  1.418319e+08      NaN      NaN    532.000000
#
#        overall_satisfaction  accommodates      bedrooms  bathrooms  \
# count          18660.000000  18660.000000  18660.000000        0.0
# mean               3.303778      2.921543      1.431833        NaN
# std                2.213003      1.319141      0.880145        NaN
# ...
